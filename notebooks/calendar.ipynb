# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 999)

# %%
cal_1611 = pd.read_csv('../data/calendar_2016-11-02.csv.gz', compression='gzip')

# %%
# temp = cal_1611[cal_1611["date"] == "2017-11-09"]
# cal_1611 = cal_1611[cal_1611["date"] >= "2017-11-06"]
cal_1611.sort_values("date", ascending=False)
# Out:
#          listing_id        date available    price
# 1074836     1359419  2017-11-01         t   $79.00
# 868700     10501802  2017-11-01         t  $110.00
# 258785       638875  2017-11-01         f      NaN
# 1883400    11124548  2017-11-01         f      NaN
# 1067990    12582732  2017-11-01         f      NaN
# 258673      4795263  2017-11-01         t   $55.00
# 1883765    12899632  2017-11-01         f      NaN
# 1068355     7176007  2017-11-01         f      NaN
# 1884130    14040855  2017-11-01         f      NaN
# 1884495    12467986  2017-11-01         f      NaN
# 1885077    11681541  2017-11-01         f      NaN
# 258055     15603164  2017-11-01         t  $222.00
# 1885225    13240929  2017-11-01         t  $260.00
# 545887      9682877  2017-11-01         t  $225.00
# 257950     15465976  2017-11-01         f      NaN
# 2241100     1261074  2017-11-01         f      NaN
# 546040     15597482  2017-11-01         f      NaN
# ...
