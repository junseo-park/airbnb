# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 999)

# %%
# listings_1611 = pd.read_csv('../data/listings_2016-11-02.csv.gz', compression='gzip')
listings_1612 = pd.read_csv('../data/listings_2016-12-03.csv.gz', compression='gzip')
listings_1701 = pd.read_csv('../data/listings_2017-01-01.csv.gz', compression='gzip')

listings_1702 = pd.read_csv('../data/listings_2017-02-02.csv.gz', compression='gzip')
listings_1703 = pd.read_csv('../data/listings_2017-03-02.csv.gz', compression='gzip')
listings_1704 = pd.read_csv('../data/listings_2017-04-02.csv.gz', compression='gzip')
listings_1705 = pd.read_csv('../data/listings_2017-05-02.csv.gz', compression='gzip')
listings_1706 = pd.read_csv('../data/listings_2017-06-02.csv.gz', compression='gzip')
listings_1707 = pd.read_csv('../data/listings_2017-07-02.csv.gz', compression='gzip')
listings_1708 = pd.read_csv('../data/listings_2017-08-02.csv.gz', compression='gzip')
listings_1709 = pd.read_csv('../data/listings_2017-09-02.csv.gz', compression='gzip')
listings_1710 = pd.read_csv('../data/listings_2017-10-02.csv.gz', compression='gzip')
listings_1711 = pd.read_csv('../data/listings_2017-11-01.csv.gz', compression='gzip')
# Out:
# /Users/valerietan/miniconda2/envs/data100/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (43) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# cleaned_listing_1611 = listings_1611.loc[:, ["id", "latitude", "longitude", "neighbourhood"]]
# cleaned_listing_1611.head()
listings_1612.head()
# Out:
#          id                            listing_url       scrape_id  \
# 0  16064495  https://www.airbnb.com/rooms/16064495  20161203092353
# 1   9904485   https://www.airbnb.com/rooms/9904485  20161203092353
# 2   7856443   https://www.airbnb.com/rooms/7856443  20161203092353
# 3   6938818   https://www.airbnb.com/rooms/6938818  20161203092353
# 4   3168359   https://www.airbnb.com/rooms/3168359  20161203092353
#
#   last_scraped                                            name  \
# 0   2016-12-03  Charming house with view of Golden Gate Bridge
# 1   2016-12-03                                     Great Room!
# 2   2016-12-03                       The Real San Francisco #2
# 3   2016-12-03                             Best Secret in Town
# 4   2016-12-03               Charming & Private Ideal location
#
#                                              summary  \
# 0  Welcome to one of the coziest and charming hom...
# 1           Quite house, clean room, nice roommates.
# ...

# %%
# cleaned_listing_1611["2016 11"] = True

# %%
# cleaned_listing_1611.head()

# %%
all_df = [listings_1612, listings_1701, listings_1702, listings_1703, listings_1704, 
         listings_1705, listings_1706, listings_1707, listings_1708, listings_1709, 
          listings_1710, listings_1711]

all_listings = ["listings_1612", "listings_1701", "listings_1702", "listings_1703", "listings_1704", 
         "listings_1705", "listings_1706", "listings_1707", "listings_1708", "listings_1709", 
          "listings_1710", "listings_1711"]

# %%
unique_listings = pd.concat(all_df, sort = False)
unique_listings = unique_listings.loc[:, ["id", "latitude", "longitude", "neighbourhood", "room_type"]]

# %%
list_1612 = listings_1612.loc[:, ["id", "latitude", "longitude", "room_type"]]

unique_id = unique_listings["id"].unique()
unique = pd.DataFrame(unique_id)
unique.columns = ["id"]
unique = unique.join(list_1612.set_index("id"), on = "id")
unique = unique.sort_values(by="id", ascending=True)
unique.head()
# Out:
#          id   latitude   longitude        room_type
# 9028    958  37.769310 -122.433856  Entire home/apt
# 6593   5021  37.762352 -122.434497  Entire home/apt
# 7867   5193  37.792581 -122.416002  Entire home/apt
# 12394  5841        NaN         NaN              NaN
# 6947   5858  37.745112 -122.421018  Entire home/apt

# %%
unique_listings.head()
# Out:
#          id   latitude   longitude      neighbourhood        room_type
# 0  16064495  37.787923 -122.484357  Richmond District  Entire home/apt
# 1   9904485  37.785487 -122.488011          Sea Cliff     Private room
# 2   7856443  37.782278 -122.492784  Richmond District  Entire home/apt
# 3   6938818  37.780659 -122.505635  Richmond District     Private room
# 4   3168359  37.779319 -122.509635  Richmond District  Entire home/apt

# %%
for i in np.arange(len(all_df)):
    all_df[i] = all_df[i].loc[:, ["id"]]
    all_df[i][all_listings[i][9:]] = True

# %%
for i in range(len(all_df)):
    unique = unique.set_index(0).join(all_df[i].set_index("id"), on=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda2/envs/data100/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-2dd8cd68e255> in <module>()
# ...

# %%
unique_listings = unique_listings.fillna(False)
# no_1611 = unique_listings[unique_listings["1612"].isna()]
unique_listings = unique_listings.sort_values("id")
unique_listings
# Out:
#             id   latitude   longitude          neighbourhood        room_type  \
# 8348       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 8705       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 9028       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 8874       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 9018       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 8621       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 8471       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 8391       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 8651       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 8613       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# 5553       958  37.769310 -122.433856        Duboce Triangle  Entire home/apt
# ...

# %%
counts = unique_listings.groupby("neighbourhood").sum()
counts.head()
unique_listings.shape
# Out:
# (106189, 17)

# %%
counts.sort_values("id", ascending=False)
# Out:
#                                                               id  \
# neighbourhood
# False                                               111035358423
# Mission District                                     98795553657
# SoMa                                                 62655248753
# Western Addition/NOPA                                52096510510
# Richmond District                                    49368397705
# Bernal Heights                                       40892992989
# Noe Valley                                           36388253480
# Nob Hill                                             35305229934
# Outer Sunset                                         34760527217
# The Castro                                           30215827526
# Downtown                                             29211355693
# Pacific Heights                                      27340853496
# Potrero Hill                                         24535149787
# ...
